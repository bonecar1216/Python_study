# %% [markdown]
# ![스크린샷 2023-12-14 오후 11.54.14.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2023-12-14 오후 11.54.22.png](data:image/png;base64,...)

# %% [markdown]
# https://www.acmicpc.net/problem/1436

# %%
n = int(input())
cnt = 0
res = 666

while True:
    if '666' in str(res):
        cnt += 1
    if cnt == n:
        break
    res += 1

print(res)
# Out:
# 500
# 166699
