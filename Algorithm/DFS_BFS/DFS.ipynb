# %%
from IPython.display import Image

# %% [markdown]
# ### DFS
#     DFS (Depth-First Search)
#     * 깊이 우선 탐색이라고 부르며, 그래프에서 깊은 부분을 우선적으로 탐색하는 알고리즘
#     * 스택 자료구조를 이용 (선입 후출, 후입 선출)

# %%
Image('DFS/IMG_03AFD78CFFC6-1.jpeg', width = 700, height =300)

# %%
Image('DFS/IMG_03AFD78CFFC6-2.jpeg', width = 700, height =300)

# %%
Image('DFS/IMG_03AFD78CFFC6-3.jpeg', width = 700, height =300)

# %%
Image('DFS/IMG_03AFD78CFFC6-4.jpeg', width = 700, height =300)

# %%
Image('DFS/IMG_5500E5F43920-1.jpeg', width = 700, height =300)

# %%
# DFS 메서드 정의
def dfs(graph, v ,visited):
    # 현재 노드를 방문 처리
    visited[v] = True
    print(v, end =' ')
    # 현재 노드와 연결된 다른 노드를 재귀적으로 방문
    for i in graph[v]:
        if not visited[i]:
            dfs(graph, i, visited)

# 각 노드가 연결된 정보를 리스트 자료형으로 표현 (2차원 리스트)
## 1번 노드 -> 2,3,8 노드와 연결
## 2번 노드 -> 1,7 노드와 연결
graph = [
    [],
    [2,3,8],
    [1,7],
    [1,4,5],
    [3,5],
    [3,4],
    [7],
    [2,6,8],
    [1,7]
]

# 각 노드가 방문된 정보를 리스트 자료형으로 표현 (1차원 리스트)
visited = [False] * 9

# 정의된 DFS 함수 호출
dfs(graph, 1, visited)
# Out:
# 1 2 7 6 8 3 4 5

# %%
def dfs(graph, v, visited):
    visited[v] = True
    print(v, end =' ')
    for i in graph[v]:
        if not visited[i]:
            dfs(graph, i, visited)

graph = [
    [],
    [2,3,8],
    [1,7],
    [1,4,5],
    [3,5],
    [3,4],
    [7],
    [2,6,8],
    [1,7]
]

# 각 노드가 방문된 정보를 리스트 자료형으로 표현 (1차원 리스트)
visited = [False] * 9

# 정의된 DFS 함수 호출
dfs(graph, 1, visited)
# Out:
# 1 2 7 6 8 3 4 5
