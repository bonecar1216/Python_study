# %% [markdown]
# ![스크린샷 2024-01-06 오후 8.36.46.png](data:image/png;base64,...)

# %% [markdown]
# https://www.acmicpc.net/problem/1912

# %%
n = int(input())
arr = list(map(int,input().split()))
dp = [0] * n
dp[0] = arr[0]
for i in range(1,n):
    dp[i] = max(dp[i-1]+arr[i],arr[i])
print(max(dp))
# Out:
# 10
# 10 -4 3 1 5 6 -35 12 21 -1
# 33
