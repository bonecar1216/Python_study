# %% [markdown]
# ![스크린샷 2024-01-07 오후 9.10.06.png](data:image/png;base64,...)

# %% [markdown]
# https://www.acmicpc.net/problem/1904

# %%
import sys
dp = [0]*1000001
dp[1] = 1
dp[2] = 2

n = int(sys.stdin.readline())
for i in range(3,n+1):
    dp[i] = (dp[i-1]+dp[i-2])%15746
print(dp[n])
# Out:
# 6
# 13
