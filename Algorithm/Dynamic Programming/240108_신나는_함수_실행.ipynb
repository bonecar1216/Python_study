# %% [markdown]
# ![스크린샷 2024-01-07 오후 8.20.23.png](data:image/png;base64,...)

# %% [markdown]
# https://www.acmicpc.net/problem/9184

# %%
import sys
dp = [[[0]*21 for _ in range(21)] for _ in range(21)]

def w(a,b,c):
    if a<=0 or b<=0 or c<=0:
        return 1
    if a>20 or b>20 or c>20:
        return w(20,20,20)
    if dp[a][b][c]:  # 값이 저장되어 있을 경우, 바로 출력
        return dp[a][b][c]
    if a<b and b<c:
        dp[a][b][c] = w(a,b,c-1) + w(a,b-1,c-1)-w(a,b-1,c)
        return dp[a][b][c]
    dp[a][b][c] = w(a-1,b,c)+w(a-1,b-1,c)+w(a-1,b,c-1)-w(a-1,b-1,c-1)
    return dp[a][b][c]

while True:
    a, b, c = map(int,sys.stdin.readline().rstrip().split())
    if a == -1 and b == -1 and c == -1:
        break
    print(f'w({a}, {b}, {c}) = {w(a,b,c)}')
# Out:
# 1 1 1
# w(1, 1, 1) = 2
# 2 2 2
# w(2, 2, 2) = 4
# 10 4 6
# w(10, 4, 6) = 523
# 50 50 50
# w(50, 50, 50) = 1048576
# -1 7 18
# w(-1, 7, 18) = 1
# -1 -1 -1
