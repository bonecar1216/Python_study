# %% [markdown]
# ![스크린샷 2023-12-16 오전 8.38.14.png](data:image/png;base64,...)

# %% [markdown]
# https://www.acmicpc.net/problem/11651

# %%
n = int(input())
points = []

for _ in range(n):
    points.append(list(map(int,input().split())))

points_sorted = sorted(points, key = lambda x: (x[1], x[0]))

for x, y in points_sorted:
    print(x, y)
