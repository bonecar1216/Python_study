# %% [markdown]
# ![스크린샷 2023-12-16 오전 8.28.04.png](data:image/png;base64,...)

# %% [markdown]
# https://www.acmicpc.net/problem/2587

# %%
num_list = []
total = 0

for _ in range(5):
    n = int(input())
    num_list.append(n)
    total += n

print(int(total/5))
num_list.sort()
print(num_list[2])
# Out:
# 10
# 40
# 30
# 60
# 30
# 34
# 30
