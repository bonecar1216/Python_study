# %% [markdown]
# # 계수 정렬

# %%
from IPython.display import Image
Image('CountSort/IMG_D1D013A758DE-1.jpeg', width = 700, height =300)

# %%
Image('CountSort/IMG_D1D013A758DE-2.jpeg', width = 700, height =300)

# %%
Image('CountSort/IMG_D1D013A758DE-3.jpeg', width = 700, height =300)

# %%
# 모든 원소의 값이 0보다 크거나 같다고 가정
array = [7,5,9,0,3,1,6,2,9,1,4,8,0,5,2]

# 모든 범위를 포함하는 리스트 선언(모든 값은 0으로 초기화)
count = [0] * (max(array) + 1)

for i in range(len(array)):
    count[array[i]] += 1  # 각 데이터에 해당하는 인덱스의 값 증가
    
for i in range(len(count)):  # 리스트에 기록된 정렬 정보 확인
    for j in range(count[i]): 
        print(i, end = ' ')  # 띄어쓰기를 구분으로 등장한 횟수만큼 인덱스 출력

# %% [markdown]
#     * 모든 데이터가 양의 정수인 상황에서 데이터의 개수(N), 데이터 중 최대값의 크기(K)일 때, 시간 복잡도는 O(N+K)
