# %% [markdown]
# *이탤릭체 텍스트![스크린샷 2023-12-28 오후 9.18.52.png](data:image/png;base64,...)*

# %% [markdown]
# https://www.acmicpc.net/problem/1037

# %%
n = int(input())
divisor_list = list(map(int,input().split()))
divisor_list.sort()
print(divisor_list[0] * divisor_list[-1])
