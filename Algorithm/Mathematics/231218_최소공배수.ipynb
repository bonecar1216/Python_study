# %% [markdown]
# ![스크린샷 2023-12-18 오후 3.37.33.png](data:image/png;base64,...)

# %% [markdown]
# https://www.acmicpc.net/problem/1934

# %%
t = int(input())

for _ in range(t):
    a, b = map(int,input().split())
    num = a * b
    while b != 0:
        a, b = b, a%b
    print(int(num/a))
# Out:
# 3
# 1 45000
# 45000
# 6 10
# 30
# 13 17
# 221
