# %% [markdown]
# ![스크린샷 2024-01-03 오후 11.00.55.png](data:image/png;base64,...)

# %% [markdown]
# https://www.acmicpc.net/problem/27433

# %%
def factorial(n):
    if n > 0:
        return n * factorial(n-1)
    else:
        return 1

n = int(input())
print(factorial(n))
# Out:
# 0
# 1
