# %% [markdown]
# ![스크린샷 2024-01-03 오후 11.06.08.png](data:image/png;base64,...)

# %% [markdown]
# https://www.acmicpc.net/problem/10870

# %%
def f_num(n):
    if n == 0 or n == 1:
        return n
    else:
        return f_num(n-1)+f_num(n-2)

n = int(input())
print(f_num(n))
# Out:
# 10
# 55
