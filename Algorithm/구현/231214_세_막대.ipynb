# %% [markdown]
# ![스크린샷 2023-12-14 오후 9.32.34.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2023-12-14 오후 9.32.42.png](data:image/png;base64,...)

# %% [markdown]
# https://www.acmicpc.net/problem/14215

# %%
a = list(map(int,input().split()))
a.sort(reverse = True)
if a[0] >= a[1] + a[2]:
    while a[0] >= a[1] + a[2]:
        a[0] -= 1
print(sum(a))
# Out:
# 41 64 16
# 113
