# %% [markdown]
# ![스크린샷 2023-12-12 오후 10.55.54.png](data:image/png;base64,...)

# %% [markdown]
# ![스크린샷 2023-12-12 오후 10.56.01.png](data:image/png;base64,...)

# %%
n = int(input())
print(n*2+1+n+(n-1))
# Out:
# 3
# 12
